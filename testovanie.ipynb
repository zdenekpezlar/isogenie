# %%
3+4
# Out:
# 7

# %%
3+6
# Out:
# 9

# %%
solve(x^3 - 1 == 0, x)
# Out:
# [x == 1/2*I*sqrt(3) - 1/2, x == -1/2*I*sqrt(3) - 1/2, x == 1]

# %%
k = GF(5);
for a in k:
    print(2*a)
# Out:
# 0
# 2
# 4
# 1
# 3

# %%
factor(2021)
# Out:
# 43 * 47

# %%
factor(x^2-4)
# Out:
# (x + 2)*(x - 2)

# %%
factor(x^4+4y^4)
# Out:
#   File "<ipython-input-7-182bba8479fe>", line 1
#     factor(x**Integer(4)+4y**Integer(4))
#                           ^
# SyntaxError: invalid syntax

# %%
EllipticCurve(GF(101),[2,3])
# Out:
# Elliptic Curve defined by y^2 = x^3 + 2*x + 3 over Finite Field of size 101

# %%
11+2
# Out:
# 13

# %%
EllipticCurve(GF(101),[2,7])
# Out:
# Elliptic Curve defined by y^2 = x^3 + 2*x + 7 over Finite Field of size 101

# %%
EllipticCurve(GF(101),[2,7]);
E.abelian_group()
# Out:
# Additive abelian group isomorphic to Z/106 embedded in Abelian group of points on Elliptic Curve defined by y^2 = x^3 + 2*x + 7 over Finite Field of size 101

# %%
E = EllipticCurve(GF(101),[2,7])
E
# Out:
# Elliptic Curve defined by y^2 = x^3 + 2*x + 7 over Finite Field of size 101

# %%
E.plot()
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
EE = EllipticCurve([-10,10])
EE
# Out:
# Elliptic Curve defined by y^2 = x^3 - 10*x + 10 over Rational Field

# %%
EE.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
E.order()
# Out:
# 106

# %%
E.cardinality()
# Out:
# 106

# %%
E.order() == E.cardinality()
# Out:
# True

# %%
E.points()
# Out:
# [(0 : 1 : 0), (2 : 25 : 1), (2 : 76 : 1), (4 : 33 : 1), (4 : 68 : 1), (6 : 29 : 1), (6 : 72 : 1), (8 : 38 : 1), (8 : 63 : 1), (9 : 42 : 1), (9 : 59 : 1), (10 : 44 : 1), (10 : 57 : 1), (11 : 42 : 1), (11 : 59 : 1), (14 : 31 : 1), (14 : 70 : 1), (15 : 33 : 1), (15 : 68 : 1), (16 : 14 : 1), (16 : 87 : 1), (17 : 45 : 1), (17 : 56 : 1), (18 : 44 : 1), (18 : 57 : 1), (19 : 6 : 1), (19 : 95 : 1), (20 : 13 : 1), (20 : 88 : 1), (23 : 10 : 1), (23 : 91 : 1), (27 : 7 : 1), (27 : 94 : 1), (30 : 10 : 1), (30 : 91 : 1), (31 : 41 : 1), (31 : 60 : 1), (32 : 32 : 1), (32 : 69 : 1), (33 : 16 : 1), (33 : 85 : 1), (39 : 4 : 1), (39 : 97 : 1), (42 : 34 : 1), (42 : 67 : 1), (45 : 25 : 1), (45 : 76 : 1), (46 : 24 : 1), (46 : 77 : 1), (47 : 46 : 1), (47 : 55 : 1), (48 : 10 : 1), (48 : 91 : 1), (54 : 25 : 1), (54 : 76 : 1), (56 : 46 : 1), (56 : 55 : 1), (57 : 22 : 1), (57 : 79 : 1), (59 : 26 : 1), (59 : 75 : 1), (60 : 47 : 1), (60 : 54 : 1), (66 : 47 : 1), (66 : 54 : 1), (67 : 5 : 1), (67 : 96 : 1), (69 : 0 : 1), (73 : 44 : 1), (73 : 57 : 1), (75 : 16 : 1), (75 : 85 : 1), (76 : 47 : 1), (76 : 54 : 1), (79 : 18 : 1), (79 : 83 : 1), (80 : 20 : 1), (80 : 81 : 1), (81 : 42 : 1), (81 : 59 : 1), (82 : 33 : 1), (82 : 68 : 1), (84 : 3 : 1), (84 : 98 : 1), (85 : 11 : 1), (85 : 90 : 1), (86 : 6 : 1), (86 : 95 : 1), (88 : 39 : 1), (88 : 62 : 1), (90 : 13 : 1), (90 : 88 : 1), (92 : 13 : 1), (92 : 88 : 1), (93 : 40 : 1), (93 : 61 : 1), (94 : 16 : 1), (94 : 85 : 1), (95 : 48 : 1), (95 : 53 : 1), (97 : 6 : 1), (97 : 95 : 1), (99 : 46 : 1), (99 : 55 : 1), (100 : 2 : 1), (100 : 99 : 1)]

# %%
EE.order()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.getattr_from_category (build/cythonized/sage/structure/category_object.c:6958)()
#     837         try:
# --> 838             return self.__cached_methods[name]
#     839         except KeyError:
#
# KeyError: 'order'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-dd55e2975e62> in <module>()
# ----> 1 EE.order()
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.__getattr__ (build/cythonized/sage/structure/category_object.c:6880)()
#     830             AttributeError: 'PrimeNumbers_with_category' object has no attribute 'sadfasdf'
#     831         """
# --> 832         return self.getattr_from_category(name)
#     833
#     834     cdef getattr_from_category(self, name):
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.getattr_from_category (build/cythonized/sage/structure/category_object.c:7043)()
#     845                 cls = self._category.parent_class
#     846
# --> 847             attr = getattr_from_other_class(self, cls, name)
#     848             self.__cached_methods[name] = attr
#     849             return attr
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/cpython/getattr.pyx in sage.cpython.getattr.getattr_from_other_class (build/cythonized/sage/cpython/getattr.c:2547)()
#     387         dummy_error_message.cls = type(self)
#     388         dummy_error_message.name = name
# --> 389         raise AttributeError(dummy_error_message)
#     390     cdef PyObject* attr = instance_getattr(cls, name)
#     391     if attr is NULL:
#
# AttributeError: 'EllipticCurve_rational_field_with_category' object has no attribute 'order'

# %%
EE.cardinality()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.getattr_from_category (build/cythonized/sage/structure/category_object.c:6958)()
#     837         try:
# --> 838             return self.__cached_methods[name]
#     839         except KeyError:
#
# KeyError: 'cardinality'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-7635c5a1b157> in <module>()
# ----> 1 EE.cardinality()
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.__getattr__ (build/cythonized/sage/structure/category_object.c:6880)()
#     830             AttributeError: 'PrimeNumbers_with_category' object has no attribute 'sadfasdf'
#     831         """
# --> 832         return self.getattr_from_category(name)
#     833
#     834     cdef getattr_from_category(self, name):
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.getattr_from_category (build/cythonized/sage/structure/category_object.c:7043)()
#     845                 cls = self._category.parent_class
#     846
# --> 847             attr = getattr_from_other_class(self, cls, name)
#     848             self.__cached_methods[name] = attr
#     849             return attr
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/cpython/getattr.pyx in sage.cpython.getattr.getattr_from_other_class (build/cythonized/sage/cpython/getattr.c:2547)()
#     387         dummy_error_message.cls = type(self)
#     388         dummy_error_message.name = name
# --> 389         raise AttributeError(dummy_error_message)
#     390     cdef PyObject* attr = instance_getattr(cls, name)
#     391     if attr is NULL:
#
# AttributeError: 'EllipticCurve_rational_field_with_category' object has no attribute 'cardinality'

# %%
EE.points()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.getattr_from_category (build/cythonized/sage/structure/category_object.c:6958)()
#     837         try:
# --> 838             return self.__cached_methods[name]
#     839         except KeyError:
#
# KeyError: 'points'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-de84a7998bb4> in <module>()
# ----> 1 EE.points()
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.__getattr__ (build/cythonized/sage/structure/category_object.c:6880)()
#     830             AttributeError: 'PrimeNumbers_with_category' object has no attribute 'sadfasdf'
#     831         """
# --> 832         return self.getattr_from_category(name)
#     833
#     834     cdef getattr_from_category(self, name):
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/category_object.pyx in sage.structure.category_object.CategoryObject.getattr_from_category (build/cythonized/sage/structure/category_object.c:7043)()
#     845                 cls = self._category.parent_class
#     846
# --> 847             attr = getattr_from_other_class(self, cls, name)
#     848             self.__cached_methods[name] = attr
#     849             return attr
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/cpython/getattr.pyx in sage.cpython.getattr.getattr_from_other_class (build/cythonized/sage/cpython/getattr.c:2547)()
#     387         dummy_error_message.cls = type(self)
#     388         dummy_error_message.name = name
# --> 389         raise AttributeError(dummy_error_message)
#     390     cdef PyObject* attr = instance_getattr(cls, name)
#     391     if attr is NULL:
#
# AttributeError: 'EllipticCurve_rational_field_with_category' object has no attribute 'points'

# %%
P = E.random_point()
P
# Out:
# (95 : 53 : 1)

# %%
P.order()
# Out:
# 106

# %%
Q = E.random_point()
Q;
Q.order()
# Out:
# 53

# %%
R = E.random_point()
R
# Out:
# (82 : 68 : 1)

# %%
R.order()
# Out:
# 53

# %%
Fq = GF(11^2);
Fq
# Out:
# Finite Field in z2 of size 11^2

# %%
Fq.gen()
# Out:
# z2

# %%
2+4
# Out:
# 6

# %%
E = EllipticCurve(GF(101),[2,7])
E
# Out:
# Elliptic Curve defined by y^2 = x^3 + 2*x + 7 over Finite Field of size 101

# %%
E.j_invariant()
# Out:
# 18

# %%
F = EllipticCurve_from_j(GF(101)(18))
F
# Out:
# Elliptic Curve defined by y^2 = x^3 + 26*x + 54 over Finite Field of size 101

# %%
E.is_quadratic_twist(F)
# Out:
# 26

# %%
F.j_invariant()
# Out:
# 18

# %%
phi = EllipticCurveIsogeny(E, E((82,68)) )
phi
# Out:
# Isogeny of degree 53 from Elliptic Curve defined by y^2 = x^3 + 2*x + 7 over Finite Field of size 101 to Elliptic Curve defined by y^2 = x^3 + 100*x + 61 over Finite Field of size 101

# %%
phi.degree()
# Out:
# 53

# %%
phi.kernel_polynomial()
# Out:
# x^26 + 86*x^25 + 42*x^24 + 59*x^23 + 83*x^22 + 18*x^21 + 22*x^20 + 77*x^19 + 2*x^18 + 66*x^17 + 7*x^16 + 59*x^15 + 14*x^14 + 44*x^13 + 29*x^12 + x^11 + 96*x^10 + 40*x^9 + 63*x^8 + 53*x^7 + 92*x^6 + 62*x^5 + 7*x^4 + 26*x^3 + 48*x^2 + 11*x + 96

# %%
phi.rational_maps()
# Out:
# ((x^53 - 30*x^52 + 47*x^51 + x^50 + 45*x^49 - 32*x^48 - 42*x^47 - 20*x^46 - 19*x^45 + 16*x^44 - 25*x^43 + 36*x^42 + 6*x^41 + 25*x^40 - 24*x^39 - 22*x^38 + 48*x^37 + 10*x^36 - 16*x^35 + 37*x^34 - 16*x^33 - 42*x^32 + 6*x^31 - 9*x^30 - 33*x^29 + 41*x^28 + 12*x^27 - 8*x^26 - 10*x^25 - 38*x^24 - 19*x^23 + 32*x^22 + 15*x^21 - 18*x^20 + 29*x^19 + 13*x^18 + 46*x^17 - 7*x^16 - 25*x^15 + 15*x^14 - 19*x^13 + 36*x^12 + 11*x^11 - 20*x^10 + 34*x^9 - 35*x^8 - 16*x^7 - 43*x^6 + 29*x^5 - 31*x^4 - 35*x^3 + 22*x^2 - 40*x + 37)/(x^52 - 30*x^51 + 6*x^50 - 31*x^49 - 42*x^48 - 23*x^47 - 42*x^46 - 7*x^45 - 30*x^44 + 4*x^43 - 48*x^42 - 29*x^41 + 21*x^40 - 31*x^39 - 32*x^38 - 38*x^37 - 11*x^36 + 29*x^35 + 19*x^34 - 26*x^33 + 22*x^32 + 42*x^31 + 37*x^30 + 25*x^29 + 50*x^28 - 13*x^27 - 12*x^26 - 9*x^25 - 38*x^24 + 30*x^23 - 31*x^22 - 9*x^21 - 22*x^20 + 40*x^19 - 35*x^18 + 46*x^17 - 47*x^16 - 5*x^15 + 28*x^14 - 22*x^13 - 21*x^12 - 44*x^11 + 19*x^10 + 10*x^9 + 16*x^8 + 33*x^7 - 26*x^6 + 10*x^5 - 22*x^4 - 12*x^3 + 45*x^2 - 9*x + 25),
#  (x^78*y - 45*x^77*y - 48*x^76*y + 19*x^75*y - 46*x^74*y - 21*x^73*y + 36*x^72*y - 33*x^71*y - 41*x^70*y - 43*x^69*y + 34*x^68*y + 50*x^67*y + 39*x^66*y - 18*x^65*y + 38*x^64*y + 34*x^63*y - 17*x^62*y - 16*x^61*y - 46*x^60*y - 45*x^59*y + 16*x^58*y + 2*x^57*y + 49*x^56*y + 9*x^55*y - 45*x^54*y + 44*x^53*y - 9*x^52*y + 3*x^51*y + 39*x^50*y + 39*x^49*y - 31*x^48*y + 39*x^47*y + 39*x^46*y + 15*x^45*y + 15*x^44*y - 44*x^43*y - 24*x^42*y + x^41*y - 49*x^40*y + 22*x^39*y - 48*x^38*y + 50*x^37*y + 47*x^36*y + 34*x^35*y + 14*x^34*y - 2*x^33*y - 50*x^32*y + 48*x^31*y - 24*x^30*y + 9*x^29*y - 26*x^28*y - 49*x^27*y + 9*x^26*y + 14*x^25*y - 32*x^24*y + 26*x^23*y - 24*x^22*y - 23*x^21*y - 29*x^20*y + 50*x^19*y - 15*x^18*y + 45*x^17*y + 29*x^16*y - 18*x^15*y - 38*x^14*y - 47*x^13*y + 31*x^12*y + 5*x^11*y - 47*x^10*y - 13*x^9*y + 21*x^8*y + x^7*y - 39*x^6*y - 32*x^5*y + 33*x^4*y + 39*x^3*y + 8*x^2*y - 16*x*y - 8*y)/(x^78 - 45*x^77 - 7*x^76 - 9*x^75 - 2*x^74 + 15*x^73 + 23*x^72 - 11*x^71 + 26*x^70 - 46*x^69 - 45*x^68 - 48*x^67 + 25*x^66 - 40*x^65 - 36*x^64 + 37*x^63 + 34*x^62 - 21*x^61 + 49*x^60 + 13*x^59 + 20*x^58 + 36*x^57 + 16*x^56 + 35*x^55 - 12*x^54 - 15*x^53 + 8*x^52 + 16*x^51 - 33*x^50 + 11*x^49 - 15*x^48 - 33*x^47 - 36*x^46 + 46*x^45 - 48*x^44 + 15*x^43 + 9*x^42 - 21*x^41 + 26*x^40 - 37*x^39 + 15*x^38 + 10*x^37 + 33*x^36 + 31*x^35 + 44*x^34 + 17*x^33 - 12*x^32 - 33*x^31 - 35*x^30 + 43*x^29 + 29*x^28 + 30*x^27 - 29*x^26 - 13*x^25 - 27*x^24 + 29*x^23 + 33*x^22 - 4*x^21 + 24*x^20 - 37*x^19 + 25*x^18 + 22*x^17 + 12*x^16 - 36*x^15 + 44*x^14 - 42*x^13 + 17*x^12 + 4*x^11 - 49*x^10 + 40*x^9 - x^8 + 34*x^7 + 20*x^6 - 29*x^5 - 42*x^4 - 35*x^3 - 33*x^2 + 17*x - 24))

# %%
S = E.random_point()
S.order()
# Out:
# 2

# %%
S
# Out:
# (69 : 0 : 1)

# %%
iso = EllipticCurveIsogeny(E, E((69,0)) )
iso
# Out:
# Isogeny of degree 2 from Elliptic Curve defined by y^2 = x^3 + 2*x + 7 over Finite Field of size 101 to Elliptic Curve defined by y^2 = x^3 + 85*x + 66 over Finite Field of size 101

# %%
iso.degree()
# Out:
# 2

# %%
iso.rational_maps()
# Out:
# ((x^2 + 32*x + 44)/(x + 32), (x^2*y - 37*x*y - 30*y)/(x^2 - 37*x + 14))

# %%
iso.kernel_polynomial()
# Out:
# x + 32
